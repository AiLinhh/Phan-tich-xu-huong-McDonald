# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path="/content/drive/MyDrive/thaysu/McDonaldsVN.npy"
post_list = np.load(path,allow_pickle=True)
post_df_full = pd.read_excel("/content/drive/MyDrive/thaysu/McDonaldsVN.xlsx")

# %%
post_df_full=post_df_full
post_df_full.head(5)
# Out:
#             post_id                                               text  \
# 0  5488063964649144  NẾU ĐỘI TUYỂN ARGENTINA ĐÃ KHƠI MÀO\nTHÌ McDON...
# 1  5477090475746493  BELLO THE GRACE QUẬN 7, McDONALD’S TỚI ĐÂY!\n\...
# 2  5477041329084741  [MINIGAME] ĐOÁN NGÀY KHAI TRƯƠNG NHÀ MỚI McDON...
# 3  5476403969148477  METRO MAN CŨNG MÊ McDONALD’S\n\n👉 Là fan cứng ...
# 4  5474038072718400  [#HappyMeal] QUÀ GIÁNG SINH SỚM CHO CÁC McFANS...
#
#                                            post_text shared_text  \
# 0  NẾU ĐỘI TUYỂN ARGENTINA ĐÃ KHƠI MÀO\nTHÌ McDON...         NaN
# 1  BELLO THE GRACE QUẬN 7, McDONALD’S TỚI ĐÂY!\n\...         NaN
# 2  [MINIGAME] ĐOÁN NGÀY KHAI TRƯƠNG NHÀ MỚI McDON...         NaN
# 3  METRO MAN CŨNG MÊ McDONALD’S\n\n👉 Là fan cứng ...         NaN
# 4  [#HappyMeal] QUÀ GIÁNG SINH SỚM CHO CÁC McFANS...         NaN
#
#    original_text                time   timestamp  \
# 0            NaN 2022-12-19 04:20:06  1671423606
# ...

# %%
post_df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        796 non-null    int64
#  1   text                           791 non-null    object
#  2   post_text                      786 non-null    object
#  3   shared_text                    6 non-null      object
#  4   original_text                  0 non-null      float64
#  5   time                           796 non-null    datetime64[ns]
#  6   timestamp                      796 non-null    int64
#  7   image                          744 non-null    object
#  8   image_lowquality               796 non-null    object
#  9   images                         796 non-null    object
#  10  images_description             796 non-null    object
#  11  images_lowquality              796 non-null    object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
post_df_full1=post_df_full
post_df_full1[['post_id', 'reactions']]
# Out:
#               post_id                                          reactions
# 0    5488063964649144         {'thích': 74, 'yêu thích': 11, 'haha': 12}
# 1    5477090475746493  {'thích': 73, 'yêu thích': 16, 'thương thương'...
# 2    5477041329084741      {'thích': 237, 'yêu thích': 10, 'phẫn nộ': 1}
# 3    5476403969148477  {'thích': 58, 'yêu thích': 7, 'haha': 1, 'phẫn...
# 4    5474038072718400  {'thích': 2570, 'yêu thích': 352, 'haha': 12, ...
# ..                ...                                                ...
# 791  3273488246106738                      {'thích': 86, 'yêu thích': 4}
# 792  3271026226352940           {'thích': 45, 'yêu thích': 5, 'haha': 1}
# 793  3269895009799395                      {'thích': 43, 'yêu thích': 6}
# 794  3260173127438250  {'thích': 62, 'yêu thích': 3, 'haha': 9, 'wow'...
# 795  3257694444352785                     {'thích': 138, 'yêu thích': 2}
#
# [796 rows x 2 columns]

# %%
post_df_full2=post_df_full[['time','timestamp' ,'reaction_count']]
post_df_full2
# Out:
#                    time   timestamp  reaction_count
# 0   2022-12-19 04:20:06  1671423606              97
# 1   2022-12-16 14:00:02  1671199202              91
# 2   2022-12-15 14:00:04  1671112804             248
# 3   2022-12-15 05:00:19  1671080419              67
# 4   2022-12-14 14:00:39  1671026439            2982
# ..                  ...         ...             ...
# 791 2020-11-11 14:00:01  1605103201              90
# 792 2020-11-10 14:00:02  1605016802              51
# 793 2020-11-10 04:00:00  1604980800              49
# 794 2020-11-06 14:00:01  1604671201              79
# 795 2020-11-05 14:00:02  1604584802             140
#
# [796 rows x 3 columns]

# %%
dates=post_df_full2['timestamp'].to_list()
y=post_df_full2['reaction_count'].to_list()
dates.reverse()
y.reverse()
print(len(dates),len(y))
print(dates)
print(y)

# type(y[0])
# dates
# Out:
# 796 796
# ...

# %%
# biểu đồ thể hiện hiệu xuất react của các bài đăng theo thời gian từ xa ngày hiện tại đến hiện tại
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
plt.plot(dates,y)
plt.show()

# %%
#convert string to dict

import ast
def check_react(react, i):
    try:
        r = ast.literal_eval(post_df_full1['reactions'][i])[react]
    except:
        r = 0
    return r

post_df_full_with_reactions = pd.DataFrame()
for i in range(len(post_df_full1)):


    post_df_full_with_reactions = post_df_full_with_reactions.append([{  
                'post_text': post_df_full1['post_text'][i], 'time': post_df_full1['time'][i],         
                'thích':check_react('thích', i),
                'yêu thích':check_react('yêu thích', i),
                'haha':check_react('haha', i),
                'wow': check_react('wow', i), 
                'buồn':check_react('buồn', i),
                'phẫn nộ':check_react('phẫn nộ', i),
                'thương thương':check_react('thương thương', i),
                'shares':post_df_full1['shares'][i],
                'comments':post_df_full1['comments'][i],
                'reaction_count':post_df_full1['reaction_count'][i]
    }])

# %%
post_df_full_with_reactions
# Out:
#                                             post_text                time  \
# 0   NẾU ĐỘI TUYỂN ARGENTINA ĐÃ KHƠI MÀO\nTHÌ McDON... 2022-12-19 04:20:06
# 0   BELLO THE GRACE QUẬN 7, McDONALD’S TỚI ĐÂY!\n\... 2022-12-16 14:00:02
# 0   [MINIGAME] ĐOÁN NGÀY KHAI TRƯƠNG NHÀ MỚI McDON... 2022-12-15 14:00:04
# 0   METRO MAN CŨNG MÊ McDONALD’S\n\n👉 Là fan cứng ... 2022-12-15 05:00:19
# 0   [#HappyMeal] QUÀ GIÁNG SINH SỚM CHO CÁC McFANS... 2022-12-14 14:00:39
# ..                                                ...                 ...
# 0   NGON KHÓ CƯỠNG VỚI ƯU ĐÃI MUA 01 TẶNG 01 🍔 + 🍔... 2020-11-11 14:00:01
# 0   McDONALD'S LUÔN Ở ĐÂY CÙNG BẠN!!!\n\nFans có b... 2020-11-10 14:00:02
# 0   SÁNG TẠO NIỀM VUI CÙNG CHIẾC HỘP #HAPPYMEAL 💝\... 2020-11-10 04:00:00
# 0   MÓN NÀO SẼ “THỐNG TRỊ” BẢNG XẾP HẠNG CÁC MÓN N... 2020-11-06 14:00:01
# 0   [MINIGAME] TRUY TÌM MENU MCDONALD’S 🍔🍟🍦\n\nTươ... 2020-11-05 14:00:02
#
#     thích  yêu thích  haha  wow  buồn  phẫn nộ  thương thương  shares  \
# ...

# %%
path="al1" + ".xlsx"
post_df_full_with_reactions.to_excel("al1" + ".xlsx", index=False)
print(path)
# Out:
# /content/drive/MyDrive/thaysu/.xlsx

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full_with_reactions['thích'], label = "Like", marker="o")
ax.plot(post_df_full['time'], post_df_full_with_reactions['yêu thích'], label = "Love", marker="o")
ax.plot(post_df_full['time'], post_df_full_with_reactions['haha'], label = "Ha Ha", marker="o")
ax.plot(post_df_full['time'], post_df_full_with_reactions['wow'], label = "Wow", marker="o")
ax.plot(post_df_full['time'], post_df_full_with_reactions['buồn'], label = "Sad", marker="o")
ax.plot(post_df_full['time'], post_df_full_with_reactions['phẫn nộ'], label = "Angry", marker="o")
ax.plot(post_df_full['time'], post_df_full_with_reactions['thương thương'], label = "Care", marker="o")
ax.plot(post_df_full['time'], post_df_full_with_reactions['shares'], label = "Shares", marker="s")
ax.plot(post_df_full['time'], post_df_full_with_reactions['comments'], label = "Comments", marker="*")
ax.plot(post_df_full['time'], post_df_full_with_reactions['reaction_count'], label = "reaction_count", marker="*")

plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full_with_reactions['thích'], label = "Like", marker="o")


plt.legend()

from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['yêu thích'], label = "Love", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['haha'], label = "Ha Ha", marker="o")

plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['wow'], label = "Wow", marker="o")

plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['buồn'], label = "Sad", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['phẫn nộ'], label = "Angry", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['thương thương'], label = "Care", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['shares'], label = "Shares", marker="s")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['comments'], label = "Comments", marker="*")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(post_df_full['time'], post_df_full_with_reactions['reaction_count'], label = "reaction_count", marker="*")

plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
print(post_df_full_with_reactions[['thích','yêu thích','haha','wow','buồn','phẫn nộ','thương thương']].corrwith(post_df_full_with_reactions['shares']))

# hiểm thị mối quan hệ Like, Love, Ha Ha, Wow, Sad, Angry, Care với cột Share
# Out:
# thích            0.399770
# yêu thích        0.734567
# haha             0.528231
# wow              0.183471
# buồn             0.366499
# phẫn nộ          0.389263
# thương thương    0.190707
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full_with_reactions['thích'], label = "Like", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full_with_reactions['yêu thích'], label = "Love", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full_with_reactions['haha'], label = "Ha Ha", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(post_df_full['time'], post_df_full_with_reactions['wow'], label = "Wow", marker="o")


plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))

# %%
# Tìm các bài viết chưa 1 từ khóa nào đó
a=post_df_full_with_reactions['post_text'].tolist()
res=[]
for i in a :
  if "ngon lắm" in str(i): 
    res.append(i)

res
# Out:
# ["CÙNG McDONALD’S VÉN MÀN “BÍ THUẬT” BÊN TRONG LY TRÀ THẠCH HẠT SEN CÁT TƯỜNG! 🕵️\u200d♂️🤫\n\nĐể có được một ly trà thạch hạt sen thơm ngậy cho các fans tha hồ thưởng thức, thì Hạt Sen chính là yếu tố “gây thương nhớ”Xem thêm của Tứ Ẩm Cát Tường ✨\n𑁍 Hạt sen tươi sau khi thu hoạch sẽ được xử lý, chế biến theo dây chuyền công nghệ hiện đại và vẫn đảm bảo các chỉ tiêu vi sinh quan trọng.\n💯 Mọi công đoạn chế biến sản phẩm đạt tiêu chuẩn ISO, đều được giám sát quy trình nghiêm ngặt, đảm bảo an toàn thực phẩm.\nBên cạnh đó, công thức “độc quyền” được McDonald’s ấp ủ bấy lâu giúp lưu lại độ dẻo - bùi - béo của hạt sen. Vì vậy, càng dễ cảm nhận được sự ngon ngọt tự nhiên của món nước 💗.\n\nKết hợp với thạch giòn dai, cùng mùi thơm nhẹ nhàng của trà tạo nên một tuyệt tác đảm bảo sẽ níu chân fans thêm nhiều lần nữa! 😉. Chỉ thêm 10K là có ngay size Grande, thử ngay và luôn một ly trà thạch hạt sen ngon lắm à nghen! 😋\n\n#McDonalds\n#McDonaldsVietnam\n#NgũẨmThịnhVượng\n#ThêmGắnKếtThêmVui\n----
# ...

# %%
# Lấy tất cả các bài viết
post_df_full_with_reactions['post_text']
text = "" 
for i in post_df_full_with_reactions['post_text']:
  text=text+str(i)+"\n"
# print(text)

# %%
a=post_df_full_with_reactions['post_text'].tolist()

for i in a:
  print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
# Import thư viện WordCloud 
from wordcloud import WordCloud
from pathlib import Path
import os
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
texto = text

wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white', 
                      max_words=300,
                      width=500, height=250
                         ).generate(texto)
plt.figure(figsize=(40,20))
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# !pip install -U nltk
# !pip install rake-nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 7.0 MB/s
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
print('The nltk version is {}.'.format(nltk.__version__))
# Out:
# The nltk version is 3.8.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from rake_nltk import Rake
r = Rake()

# %%
r.extract_keywords_from_text(text)

# %%
# r.get_ranked_phrases()
res=r.get_ranked_phrases_with_scores()
print(res)
# Out:
# [(2547.3615477651942, 'để ăn sập combo châu âu nào fans ơii 🥳 🥳 lật ngay thực đơn 5 món hương vịxem thêm châu âu ‘’ độc nhất vô nhị ’’: 🍔 burger gà phô mai kiểu pháp 🇫🇷 🍔 burger bò sốt bolognese kiểu ý 🇮🇹 🍟 khoai tây chiên kèm thịt xông khói anh quốc 🇬🇧 🍹 mojito anh đào đến từ tây ban nha 🇪🇸 🍨 kem sundae bánh waffle kiểu bỉ 🇧🇪 👏 còn chờ gì mà không mau sửa soạn váy áo xúng xính và kèm theo hội bạn thân để cùng ngồi vào bàn tiệc châu âu thịnh soạn lại còn được giảm giá đến 50'), (2280.015340145071, 'trên toàn quốc 👉 ưu đãi có thời hạn 30 ngày kể từ ngày phát hành mã ưu đãi 👉 ưu đãi không sử dụng hết trong chu kỳ không cộng dồn sang chu kỳ sau 👉 áp dụng nhóm sản phẩm nhất định theo gói ưu đãi 👉 ưu đãi này không thể quy đổi ra tiền mặt 👉 ưu đãi không áp dụng cùng các chương trình khuyến mãi khác 👉 không áp dụng cho dịch vụ giao hàng tận nơi 👉 vui lòng đưa ưu đãi cho nhân viên trước khi đổi sản phẩm hoặc quét mã ưu đãi trước khi đặt hàng trên máy tự động 👉 mỗi ưu đãi chỉ dùng trên 1 tài 
# ...
